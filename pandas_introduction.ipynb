# %%
import pandas as pd

# %%
pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'sutun1':["deger_1","deger_2"]})
# Out:
#     sutun1
# 0  deger_1
# 1  deger_2

# %%
deger_1 = "eren gemici"
a = pd.DataFrame({'sutun1':[deger_1,"deger_2"]},index= ['index_1','index_2'])

# %%
a
# Out:
#               sutun1
# index_1  eren gemici
# index_2      deger_2

# %%
pd.Series([1, 2, 3, 4, 5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
""" name parametresi ile data frame ya da series e isim verilebilir """
""" dtype parametresi ile de dataframe deki veri tipini belirtebiliriz. """
pd.Series([30.8, 35, 40], index=['2015 Sales', '2016 Sales', '2017 Sales'], name='Product A',dtype = int)
# Out:
# 2015 Sales    30.8
# 2016 Sales    35.0
# 2017 Sales    40.0
# Name: Product A, dtype: float64

# %% [markdown]
# # **.CSV dosyalarını okumak**

# %%
data_path = f"/content/cumulative.csv"
data = pd.read_csv(data_path, index_col = 0)

""" index_col parametresi sayesinde index sütununu
 yana kaydırıp kirliliğe engel olmuş oluyoruz"""
# Out:
# ' index_col parametresi sayesinde index sütununu\n yana kaydırıp kirliliğe engel olmuş oluyoruz'

# %%
data
# Out:
#           kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1      10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 2      10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 3      10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 5      10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...         ...        ...           ...             ...              ...
# 9560   10031643  K07984.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9561   10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562   10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9563   10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9564   10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
# ...

# %%
#baştan örnekleri sıralıyor
data.head()
# Out:
#   File "<ipython-input-18-05f5476d16c8>", line 2
#     data.head(5:16)
#                ^
# SyntaxError: invalid syntax

# %%
data.tail()
# Out:
#           kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# rowid
# 9550    8460634  K07887.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9551    8488381  K07888.01         NaN       CANDIDATE        CANDIDATE
# 9552    8489260  K07889.01         NaN       CANDIDATE        CANDIDATE
# 9553    8560927  K07897.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9554    8565912  K07898.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9555    8308347  K03761.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9556    2697935  K03853.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9557    8258160  K03870.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9558   11911561  K03875.01         NaN       CANDIDATE        CANDIDATE
# 9559    8765560  K03891.01         NaN       CANDIDATE        CANDIDATE
# 9560   10031643  K07984.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# 9561   10090151  K07985.01         NaN  FALSE POSITIVE   FALSE POSITIVE
# ...

# %%
data.shape
# Out:
# (9564, 49)

# %%
fruit_sales = pd.DataFrame({'Apples':[35,41],'Bananas':[21,34]},index=['2017 Sales','2018 Sales'])

# %%
fruit_sales
# Out:
#             Apples  Bananas
# 2017 Sales      35       21
# 2018 Sales      41       34

# %%
ingredients = pd.Series(['4 cups','1 cup','2 large','1 can'],index=['Flour','Milk','Eggs','Spam'],name="Breakfast" )
ingredients
# Out:
# Flour     4 cups
# Milk       1 cup
# Eggs     2 large
# Spam       1 can
# Name: Breakfast, dtype: object

# %%
ingredients.to_csv("ingredients.csv")

# %% [markdown]
# #** Indexing,Selecting,Assigning**

# %%
"""
Dataset içerisindeki columnlardan birini incelemek amacıyla çekip
bir pd.series halinde kullanmak için dataset.column ifadesini kullanabiliriz.
"""
data.kepid
# Out:
# rowid
# 1       10797460
# 2       10797460
# 3       10811496
# 4       10848459
# 5       10854555
#           ...
# 9560    10031643
# 9561    10090151
# 9562    10128825
# 9563    10147276
# 9564    10156110
# Name: kepid, Length: 9564, dtype: int64

# %%
data.kepid[9564]
data['kepid'][9564]
# Out:
# 10156110

# %%
"""
.iloc index tabanlı şekilde dataframeden data çekmek için kullanılır

"""
# Out:
# '\n.iloc index tabanlı şekilde dataframeden data çekmek için kullanılır\n\n'

# %%
data.iloc[0]
# Out:
# kepid                       10797460
# kepoi_name                 K00752.01
# kepler_name             Kepler-227 b
# koi_disposition            CONFIRMED
# koi_pdisposition           CANDIDATE
# koi_score                        1.0
# koi_fpflag_nt                      0
# koi_fpflag_ss                      0
# koi_fpflag_co                      0
# koi_fpflag_ec                      0
# koi_period                  9.488036
# koi_period_err1             0.000028
# koi_period_err2            -0.000028
# koi_time0bk                170.53875
# koi_time0bk_err1             0.00216
# koi_time0bk_err2            -0.00216
# koi_impact                     0.146
# koi_impact_err1                0.318
# koi_impact_err2               -0.146
# koi_duration                  2.9575
# koi_duration_err1             0.0819
# koi_duration_err2            -0.0819
# koi_depth                      615.8
# koi_depth_err1                  19.5
# koi_depth_err2                 -19.5
# ...

# %%
"""
iloc komutunda seçeceğimiz column ve rowları virgül ile ayırarak
: ifadesiyle sıralayarak seçip çağırabiliriz.

"""

data.iloc[0:5,0:9]
# Out:
#           kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1      10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 2      10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 3      10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 5      10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
#
#        koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co
# rowid
# 1          1.000              0              0              0
# 2          0.969              0              0              0
# 3          0.000              0              1              0
# 4          0.000              0              1              0
# 5          1.000              0              0              0

# %%
data.iloc[[0,1,2], 5]
# Out:
# rowid
# 1    1.000
# 2    0.969
# 3    0.000
# Name: koi_score, dtype: float64

# %%
data
# Out:
#           kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1      10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 2      10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 3      10811496  K00753.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 4      10848459  K00754.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 5      10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# ...         ...        ...           ...             ...              ...
# 9560   10031643  K07984.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9561   10090151  K07985.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9562   10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
# 9563   10147276  K07987.01           NaN  FALSE POSITIVE   FALSE POSITIVE
# 9564   10156110  K07989.01           NaN  FALSE POSITIVE   FALSE POSITIVE
#
# ...

# %%
"""
loc komutuyla string based location fonksiyonu kullanabiliyoruz
"""


data.loc[5,['kepoi_name','kepler_name']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-b4f3c5171352> in <cell line: 6>()
#       4
#       5
# ----> 6 data.loc[5,['rowid','kepoi_name','kepler_name']]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1245         with suppress(IndexingError):
#    1246             tup = self._expand_ellipsis(tup)
# -> 1247             return self._getitem_lowerdim(tup)
#    1248
#    1249         # no multi-index, so validate all of the indexers
#
# ...

# %%
data.loc[:, ['kepler_name','koi_score']]
# Out:
#         kepler_name  koi_score
# rowid
# 1      Kepler-227 b      1.000
# 2      Kepler-227 c      0.969
# 3               NaN      0.000
# 4               NaN      0.000
# 5      Kepler-664 b      1.000
# ...             ...        ...
# 9560            NaN      0.000
# 9561            NaN      0.000
# 9562            NaN      0.497
# 9563            NaN      0.021
# 9564            NaN      0.000
#
# [9564 rows x 2 columns]

# %% [markdown]
# # **Index Manipülasyonu**

# %%
#set_index komutu ile belirlenen bir sütunu index olarak belirleyebiliyoruz.

a = data.set_index("kepoi_name")

# %%
#durum belirterek bool çıktılar alabiliyoruz.

data.koi_score >= 0.5
data.koi_disposition == "CONFIRMED"
# Out:
# rowid
# 1        True
# 2        True
# 3       False
# 4       False
# 5        True
#         ...
# 9560    False
# 9561    False
# 9562    False
# 9563    False
# 9564    False
# Name: koi_disposition, Length: 9564, dtype: bool

# %%
"""
alacağımız veriyi kontrol etmek için loc ifadesi
durum belirteçleri ile birlikte kullanılabilir
"""
data.loc[data.koi_score >= 0.3]
# Out:
#           kepid kepoi_name   kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1      10797460  K00752.01  Kepler-227 b       CONFIRMED        CANDIDATE
# 2      10797460  K00752.02  Kepler-227 c       CONFIRMED        CANDIDATE
# 5      10854555  K00755.01  Kepler-664 b       CONFIRMED        CANDIDATE
# 6      10872983  K00756.01  Kepler-228 d       CONFIRMED        CANDIDATE
# 7      10872983  K00756.02  Kepler-228 c       CONFIRMED        CANDIDATE
# ...         ...        ...           ...             ...              ...
# 9551    8488381  K07888.01           NaN       CANDIDATE        CANDIDATE
# 9552    8489260  K07889.01           NaN       CANDIDATE        CANDIDATE
# 9558   11911561  K03875.01           NaN       CANDIDATE        CANDIDATE
# 9559    8765560  K03891.01           NaN       CANDIDATE        CANDIDATE
# 9562   10128825  K07986.01           NaN       CANDIDATE        CANDIDATE
#
# ...

# %%
data.loc[data.koi_disposition.isin(["CONFIRMED"])]
# Out:
#           kepid kepoi_name    kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1      10797460  K00752.01   Kepler-227 b       CONFIRMED        CANDIDATE
# 2      10797460  K00752.02   Kepler-227 c       CONFIRMED        CANDIDATE
# 5      10854555  K00755.01   Kepler-664 b       CONFIRMED        CANDIDATE
# 6      10872983  K00756.01   Kepler-228 d       CONFIRMED        CANDIDATE
# 7      10872983  K00756.02   Kepler-228 c       CONFIRMED        CANDIDATE
# ...         ...        ...            ...             ...              ...
# 9310    7347246  K03014.01  Kepler-1411 b       CONFIRMED        CANDIDATE
# 9354    8895758  K03106.01  Kepler-1427 b       CONFIRMED        CANDIDATE
# 9356    6196457  K00285.03    Kepler-92 d       CONFIRMED   FALSE POSITIVE
# 9480    7503885  K03417.01  Kepler-1494 b       CONFIRMED        CANDIDATE
# 9541    3645438  K04385.02  Kepler-1600 b       CONFIRMED        CANDIDATE
#
# ...

# %%
data.loc[data.kepler_name.notnull()]
# Out:
#           kepid kepoi_name    kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1      10797460  K00752.01   Kepler-227 b       CONFIRMED        CANDIDATE
# 2      10797460  K00752.02   Kepler-227 c       CONFIRMED        CANDIDATE
# 5      10854555  K00755.01   Kepler-664 b       CONFIRMED        CANDIDATE
# 6      10872983  K00756.01   Kepler-228 d       CONFIRMED        CANDIDATE
# 7      10872983  K00756.02   Kepler-228 c       CONFIRMED        CANDIDATE
# ...         ...        ...            ...             ...              ...
# 9310    7347246  K03014.01  Kepler-1411 b       CONFIRMED        CANDIDATE
# 9354    8895758  K03106.01  Kepler-1427 b       CONFIRMED        CANDIDATE
# 9356    6196457  K00285.03    Kepler-92 d       CONFIRMED   FALSE POSITIVE
# 9480    7503885  K03417.01  Kepler-1494 b       CONFIRMED        CANDIDATE
# 9541    3645438  K04385.02  Kepler-1600 b       CONFIRMED        CANDIDATE
#
# ...

# %% [markdown]
# # **ASSIGNING DATA**

# %%
data['kepler_name'] = 'kepler'

# %%
data['kepid'] = range(len(data),0,-1)

# %%
data['kepid']
# Out:
# rowid
# 1       9564
# 2       9563
# 3       9562
# 4       9561
# 5       9560
#         ...
# 9560       5
# 9561       4
# 9562       3
# 9563       2
# 9564       1
# Name: kepid, Length: 9564, dtype: int64

# %%
data.kepler_name.iloc[:10]
# Out:
# rowid
# 1     kepler
# 2     kepler
# 3     kepler
# 4     kepler
# 5     kepler
# 6     kepler
# 7     kepler
# 8     kepler
# 9     kepler
# 10    kepler
# Name: kepler_name, dtype: object

# %%
data.iloc[[1,2,3,5,8],:]
# Out:
#        kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# rowid
# 2       9563  K00752.02      kepler       CONFIRMED        CANDIDATE
# 3       9562  K00753.01      kepler  FALSE POSITIVE   FALSE POSITIVE
# 4       9561  K00754.01      kepler  FALSE POSITIVE   FALSE POSITIVE
# 6       9559  K00756.01      kepler       CONFIRMED        CANDIDATE
# 9       9556  K00114.01      kepler  FALSE POSITIVE   FALSE POSITIVE
#
#        koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# rowid
# 2          0.969              0              0              0              0
# 3          0.000              0              1              0              0
# 4          0.000              0              1              0              0
# 6          1.000              0              0              0              0
# 9          0.000              0              1              1              0
#
# ...

# %%
df = data.loc[[1,10,100,1000],['kepler_name','koi_disposition','koi_score','koi_slogg']]
df
# Out:
#       kepler_name koi_disposition  koi_score  koi_slogg
# rowid
# 1          kepler       CONFIRMED        1.0      4.467
# 10         kepler       CONFIRMED        1.0      4.485
# 100        kepler       CONFIRMED        NaN      4.556
# 1000       kepler       CONFIRMED        1.0      4.489

# %%
df = data.loc[:100,['kepler_name','koi_disposition']]
df
# Out:
#       kepler_name koi_disposition
# rowid
# 1          kepler       CONFIRMED
# 2          kepler       CONFIRMED
# 3          kepler  FALSE POSITIVE
# 4          kepler  FALSE POSITIVE
# 5          kepler       CONFIRMED
# ...           ...             ...
# 96         kepler  FALSE POSITIVE
# 97         kepler       CONFIRMED
# 98         kepler       CONFIRMED
# 99         kepler       CONFIRMED
# 100        kepler       CONFIRMED
#
# [100 rows x 2 columns]

# %%
confirmed_keplers = data.loc[data.koi_disposition == 'CONFIRMED']
confirmed_keplers
# Out:
#        kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1       9564  K00752.01      kepler       CONFIRMED        CANDIDATE
# 2       9563  K00752.02      kepler       CONFIRMED        CANDIDATE
# 5       9560  K00755.01      kepler       CONFIRMED        CANDIDATE
# 6       9559  K00756.01      kepler       CONFIRMED        CANDIDATE
# 7       9558  K00756.02      kepler       CONFIRMED        CANDIDATE
# ...      ...        ...         ...             ...              ...
# 9310     255  K03014.01      kepler       CONFIRMED        CANDIDATE
# 9354     211  K03106.01      kepler       CONFIRMED        CANDIDATE
# 9356     209  K00285.03      kepler       CONFIRMED   FALSE POSITIVE
# 9480      85  K03417.01      kepler       CONFIRMED        CANDIDATE
# 9541      24  K04385.02      kepler       CONFIRMED        CANDIDATE
#
#        koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# rowid
# ...

# %%
data.koi_score.describe()
# Out:
# count    8054.000000
# mean        0.480829
# std         0.476928
# min         0.000000
# 25%         0.000000
# 50%         0.334000
# 75%         0.998000
# max         1.000000
# Name: koi_score, dtype: float64

# %%
data.kepoi_name.describe()
# Out:
# count          9564
# unique         9564
# top       K00752.01
# freq              1
# Name: kepoi_name, dtype: object

# %%
kepoi_nm = data.kepoi_name.unique()
print(kepoi_nm)
# Out:
# ['K00752.01' 'K00752.02' 'K00753.01' ... 'K07986.01' 'K07987.01'
#  'K07989.01']

# %%
data.koi_score.value_counts()
# Out:
# 0.000    3482
# 1.000    1777
# 0.999     229
# 0.998     143
# 0.997     101
#          ...
# 0.795       1
# 0.823       1
# 0.170       1
# 0.865       1
# 0.497       1
# Name: koi_score, Length: 650, dtype: int64

# %%
"""


"""
data_mean = data.koi_score.mean()
data.koi_score.map(lambda p:p - data_mean)
# Out:
# rowid
# 1       0.519171
# 2       0.488171
# 3      -0.480829
# 4      -0.480829
# 5       0.519171
#           ...
# 9560   -0.480829
# 9561   -0.480829
# 9562    0.016171
# 9563   -0.459829
# 9564   -0.480829
# Name: koi_score, Length: 9564, dtype: float64

# %%
def remean_points(row):
  row.koi_score = row.koi_score - data_mean
  return row

data.apply(remean_points, axis= 'columns')
# Out:
#        kepid kepoi_name kepler_name koi_disposition koi_pdisposition  \
# rowid
# 1       9564  K00752.01      kepler       CONFIRMED        CANDIDATE
# 2       9563  K00752.02      kepler       CONFIRMED        CANDIDATE
# 3       9562  K00753.01      kepler  FALSE POSITIVE   FALSE POSITIVE
# 4       9561  K00754.01      kepler  FALSE POSITIVE   FALSE POSITIVE
# 5       9560  K00755.01      kepler       CONFIRMED        CANDIDATE
# ...      ...        ...         ...             ...              ...
# 9560       5  K07984.01      kepler  FALSE POSITIVE   FALSE POSITIVE
# 9561       4  K07985.01      kepler  FALSE POSITIVE   FALSE POSITIVE
# 9562       3  K07986.01      kepler       CANDIDATE        CANDIDATE
# 9563       2  K07987.01      kepler  FALSE POSITIVE   FALSE POSITIVE
# 9564       1  K07989.01      kepler  FALSE POSITIVE   FALSE POSITIVE
#
#        koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# rowid
# ...

# %%
data.kepoi_name + " - " + data.koi_disposition
# Out:
# rowid
# 1            K00752.01 - CONFIRMED
# 2            K00752.02 - CONFIRMED
# 3       K00753.01 - FALSE POSITIVE
# 4       K00754.01 - FALSE POSITIVE
# 5            K00755.01 - CONFIRMED
#                    ...
# 9560    K07984.01 - FALSE POSITIVE
# 9561    K07985.01 - FALSE POSITIVE
# 9562         K07986.01 - CANDIDATE
# 9563    K07987.01 - FALSE POSITIVE
# 9564    K07989.01 - FALSE POSITIVE
# Length: 9564, dtype: object

# %% [markdown]
# # **GROUPING AND SORTING**

# %%
import pandas as pd

# %%
file_path = f"/content/Titanic-Dataset.csv"
data = pd.read_csv(file_path, index_col=0)

# %%
data
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
data.groupby('Sex').Sex.count()
# Out:
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64

# %%
data.groupby('Embarked').Embarked.count().min()
# Out:
# 77

# %%
data.groupby('Embarked').apply(lambda df: df.Name.iloc[0])
# Out:
# Embarked
# C    Cumings, Mrs. John Bradley (Florence Briggs Th...
# Q                                     Moran, Mr. James
# S                              Braund, Mr. Owen Harris
# dtype: object

# %%
data.groupby(['Embarked','Sex']).apply(lambda df: df.loc[df.Pclass[0]])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data_path = f"/content/winemag-data_first150k.csv"
data = pd.read_csv(data_path,index_col=0)

# %%
import numpy as np

# %%
data_na_clean = data.dropna()
data_na_clean
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 8           US  This re-named vineyard was formerly bottled as...
# 9           US  The producer sources from two blocks of the vi...
# ...        ...                                                ...
# 150889      US  A bizarre style of wine. The aromas are Port-l...
# 150892      US  A light, earthy wine, with violet, berry and t...
# 150914      US  Old-gold in color, and thick and syrupy. The a...
# 150915      US  Decades ago, Beringer’s then-winemaker Myron N...
# 150916      US  An impressive wine that presents a full bouque...
#
#                           designation  points  price    province  \
# 0                   Martha's Vineyard      96  235.0  California
# ...

# %%
data.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      5.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      6.0
# 88      6.0
# 89      7.0
# 90      5.0
# 91      8.0
# 92     11.0
# 93     12.0
# 94     15.0
# 95     20.0
# 96     20.0
# 97     42.0
# 98     50.0
# 99     65.0
# 100    65.0
# Name: price, dtype: float64

# %%
data.groupby('winery').apply(lambda df: data.description[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Albania   Mirditë             Albania
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# Australia Australia Other   Australia
#           New South Wales   Australia
# ...                               ...
# Uruguay   Juanico             Uruguay
#           Montevideo          Uruguay
#           Progreso            Uruguay
#           San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Albania   Mirditë           This garnet-colored wine made from 100% Kallme...
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# Australia Australia Other   This big wine presents a sophisticated bouquet...
# ...

# %%
data.groupby(['country']).price.agg([len, min, max])
# Out:
#                           len   min     max
# country
# Albania                     2  20.0    20.0
# Argentina                5631   4.0   250.0
# Australia                4957   5.0   850.0
# Austria                  3057   8.0  1100.0
# Bosnia and Herzegovina      4  12.0    13.0
# Brazil                     25  11.0    35.0
# Bulgaria                   77   7.0    28.0
# Canada                    196  12.0   145.0
# Chile                    5816   5.0   400.0
# China                       3   7.0    27.0
# Croatia                    89  12.0    65.0
# Cyprus                     31  10.0    22.0
# Czech Republic              6  15.0    25.0
# Egypt                       3   NaN     NaN
# England                     9  38.0    75.0
# France                  21098   5.0  2300.0
# Georgia                    43   9.0    40.0
# Germany                  2452   5.0   775.0
# Greece                    884   7.0   120.0
# Hungary                   231   7.0   764.0
# ...

# %%
countries_reviewed = data.groupby(['country', 'province']).description.agg([len])
countries_reviewed.head()
# Out:
#                              len
# country   province
# Albania   Mirditë              2
# Argentina Mendoza Province  4742
#           Other              889
# Australia Australia Other    553
#           New South Wales    246

# %%
mi = countries_reviewed.index
type(data)
countries_reviewed.len
# Out:
# country    province
# Albania    Mirditë                2
# Argentina  Mendoza Province    4742
#            Other                889
# Australia  Australia Other      553
#            New South Wales      246
#                                ...
# Uruguay    Juanico               19
#            Montevideo             3
#            Progreso               5
#            San Jose              15
#            Uruguay               18
# Name: len, Length: 455, dtype: int64

# %%
reset = countries_reviewed.reset_index()

# %% [markdown]
# # **SORTING**

# %%
reset.sort_values(by='len',ascending=0,ignore_index=1,na_position='first')
# Out:
#          country                                province    len
# 0             US                              California  44508
# 1             US                              Washington   9750
# 2          Italy                                 Tuscany   7281
# 3         France                                Bordeaux   6111
# 4          Spain                          Northern Spain   4892
# ..           ...                                     ...    ...
# 450  Switzerland                               Neuchâtel      1
# 451  Switzerland                                  Ticino      1
# 452  Switzerland                                  Valais      1
# 453  Switzerland  Vino da Tavola della Svizzera Italiana      1
# 454       Greece                          Krania Olympus      1
#
# [455 rows x 3 columns]

# %%
reset.sort_index()
# Out:
#        country          province   len
# 0      Albania           Mirditë     2
# 1    Argentina  Mendoza Province  4742
# 2    Argentina             Other   889
# 3    Australia   Australia Other   553
# 4    Australia   New South Wales   246
# ..         ...               ...   ...
# 450    Uruguay           Juanico    19
# 451    Uruguay        Montevideo     3
# 452    Uruguay          Progreso     5
# 453    Uruguay          San Jose    15
# 454    Uruguay           Uruguay    18
#
# [455 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'],ascending=False)
# Out:
#                              len
# country   province
# Uruguay   Canelones           19
#           Juanico             19
#           Uruguay             18
#           San Jose            15
#           Colonia              6
# ...                          ...
# Australia Tasmania            47
#           Queensland           3
# Argentina Mendoza Province  4742
#           Other              889
# Albania   Mirditë              2
#
# [455 rows x 1 columns]

# %%
data.price.dtype
# Out:
# dtype('float64')

# %%
data.dtypes
# Out:
# country         object
# description     object
# designation     object
# points           int64
# price          float64
# province        object
# region_1        object
# region_2        object
# variety         object
# winery          object
# dtype: object

# %%
data.points.astype('int64')
# Out:
# 0         96
# 1         96
# 2         96
# 3         96
# 4         95
#           ..
# 150925    91
# 150926    91
# 150927    91
# 150928    90
# 150929    90
# Name: points, Length: 150930, dtype: int64

# %%
data.points.astype('float64')
# Out:
# 0         96.0
# 1         96.0
# 2         96.0
# 3         96.0
# 4         95.0
#           ...
# 150925    91.0
# 150926    91.0
# 150927    91.0
# 150928    90.0
# 150929    90.0
# Name: points, Length: 150930, dtype: float64

# %%
data.index.dtype
# Out:
# dtype('int64')

# %%
data2 = data.set_index('province')

# %%
data2.index.dtype
# Out:
# dtype('O')

# %%
data2
# Out:
#                    country                                        description  \
# province
# California              US  This tremendous 100% varietal wine hails from ...
# Northern Spain       Spain  Ripe aromas of fig, blackberry and cassis are ...
# California              US  Mac Watson honors the memory of a wine once ma...
# Oregon                  US  This spent 20 months in 30% new French oak, an...
# Provence            France  This is the top wine from La Bégude, named aft...
# ...                    ...                                                ...
# Southern Italy       Italy  Many people feel Fiano represents southern Ita...
# Champagne           France  Offers an intriguing nose with ginger, lime an...
# Southern Italy       Italy  This classic example comes from a cru vineyard...
# Champagne           France  A perfect salmon shade, with scents of peaches...
# Northeastern Italy   Italy  More Pinot Grigios should taste like this. A r...
#
# ...

# %%
data[pd.isnull(data.country)]
# Out:
#        country                                        description  \
# 1133       NaN  Delicate white flowers and a spin of lemon pee...
# 1440       NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 68226      NaN  From first sniff to last, the nose never makes...
# 113016     NaN  From first sniff to last, the nose never makes...
# 135696     NaN  From first sniff to last, the nose never makes...
#
#          designation  points  price province region_1 region_2     variety  \
# 1133       Askitikos      90   17.0      NaN      NaN      NaN   Assyrtiko
# 1440            Shah      90   30.0      NaN      NaN      NaN   Red Blend
# 68226   Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 113016  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
# 135696  Piedra Feliz      81   15.0      NaN      NaN      NaN  Pinot Noir
#
#            winery
# 1133     Tsililis
# 1440    Büyülübağ
# 68226     Chilcas
# 113016    Chilcas
# 135696    Chilcas

# %%
data.region_2.fillna('bilinmeyen')
# Out:
# 0                      Napa
# 1                bilinmeyen
# 2                    Sonoma
# 3         Willamette Valley
# 4                bilinmeyen
#                 ...
# 150925           bilinmeyen
# 150926           bilinmeyen
# 150927           bilinmeyen
# 150928           bilinmeyen
# 150929           bilinmeyen
# Name: region_2, Length: 150930, dtype: object

# %%
data.designation.replace("Shah","bilmediğim_yer")
# Out:
# 0                            Martha's Vineyard
# 1         Carodorum Selección Especial Reserva
# 2                Special Selected Late Harvest
# 3                                      Reserve
# 4                                   La Brûlade
#                           ...
# 150925                                     NaN
# 150926                          Cuvée Prestige
# 150927                           Terre di Dora
# 150928                         Grand Brut Rosé
# 150929                                     NaN
# Name: designation, Length: 150930, dtype: object

# %%
data
# Out:
#        country                                        description  \
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
#                                  designation  points  price  \
# 0                          Martha's Vineyard      96  235.0
# ...

# %%
data.country.replace("US","Amerika")
# Out:
# 0         Amerika
# 1           Spain
# 2         Amerika
# 3         Amerika
# 4          France
#            ...
# 150925      Italy
# 150926     France
# 150927      Italy
# 150928     France
# 150929      Italy
# Name: country, Length: 150930, dtype: object
